# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_csv('/content/diabetes (1).csv')

# %%
Data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Data.fillna(value=0,inplace=True)

# %%
Data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
Data.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
Data.SkinThickness.value_counts()
# Out:
# SkinThickness
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 33     20
# 28     20
# 18     20
# 31     19
# 19     18
# 39     18
# 29     17
# 40     16
# 25     16
# 26     16
# 22     16
# 37     16
# 41     15
# 35     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 46      8
# 34      8
# 12      7
# 38      7
# 11      6
# 43      6
# 16      6
# 45      6
# 14      6
# 44      5
# 10      5
# 48      4
# 47      4
# 49      3
# 50      3
# 8       2
# 7       2
# 52      2
# 54      2
# 63      1
# 60      1
# 56      1
# 51      1
# 99      1
# Name: count, dtype: int64

# %%
Data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
Data.shape
# Out:
# (768, 9)

# %%
x = Data.drop(columns = 'Outcome', axis=1)
y = Data['Outcome']
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
scaler = StandardScaler()
scaler.fit(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
Data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
standardized_data=scaler.transform(x)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# SVC(kernel='linear')

# %%
x_train_prediction=classifier.predict(x_train)
train_data_accuracy=accuracy_score(x_train_prediction,y_train)

# %%
print("Accuracy:",train_data_accuracy)
# Out:
# Accuracy: 0.7833876221498371

# %%
classifier= svm.SVC(kernel='linear') # Re-define classifier for heart disease analysis
classifier.fit(x_train,y_train)

# %%
print("Test accuracy:",test_data_acuracy)
# Out:
# Test accuracy: 0.7727272727272727

# %%
real_data=(3,126,60,0,0,30.1,0.349,47)
real_data_np = np.asarray(real_data)
real_data_reshape = real_data_np.reshape(1,-1)
std_data = scaler.transform(real_data_reshape)
print(std_data)
# Out:
# [[-0.25095213  0.1597866  -0.47073225 -1.28821221 -0.69289057 -0.24020459
#   -0.37110101  1.17073215]]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = classifier.predict(std_data)
while prediction[0]==0:
  print("Non-diabetic")
  break
while prediction[0]==1:
  print("Diabetic")
  break
# Out:
# Non-diabetic
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# !pip install nltk

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('     ')

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tag import pos_tag
nltk.download('averaged_perceptron_tagger_eng')

nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def tokenize_text(text):
    tokens = word_tokenize(text)
    return tokens

# %%
def lowercase_text(tokens):
    tokens = [token.lower() for token in tokens]
    return tokens

# %%
def remove_stopwords(tokens):
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# %%
def stem_tokens(tokens):
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens

# %%
def lemmatize_tokens(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return lemmatized_tokens

# %%
def pos_tag_tokens(tokens):
    pos_tags = pos_tag(tokens)
    return pos_tags

# %%
text = "This is an example sentence for demonstrating NLP preprocessing."

tokens = word_tokenize(text)
tokens = lowercase_text(tokens)
tokens = remove_stopwords(tokens)
stemmed_tokens = stem_tokens(tokens)
lemmatized_tokens = lemmatize_tokens(tokens)
pos_tags = pos_tag_tokens(tokens)

print("Tokens:", tokens)
print("Stemmed Tokens:", stemmed_tokens)
print("Lemmatized Tokens:", lemmatized_tokens)
print("POS Tags:", pos_tags)
# Out:
# Tokens: ['example', 'sentence', 'demonstrating', 'nlp', 'preprocessing', '.']
# Stemmed Tokens: ['exampl', 'sentenc', 'demonstr', 'nlp', 'preprocess', '.']
# Lemmatized Tokens: ['example', 'sentence', 'demonstrating', 'nlp', 'preprocessing', '.']
# POS Tags: [('example', 'NN'), ('sentence', 'NN'), ('demonstrating', 'VBG'), ('nlp', 'JJ'), ('preprocessing', 'NN'), ('.', '.')]

# %%
# prompt: Heart disease analysis using dataset

input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')

# %%
# !unzip "/content/archive (2).zip"
# Out:
# Archive:  /content/archive (2).zip
#   inflating: heart.csv

# %%
import numpy as np

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('/content/heart.csv')

# %%
Data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
Data.fillna(value=0,inplace=True)

# %%
Data.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
Data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
Data.s
